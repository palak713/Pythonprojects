# %%
pip install pytube3

# %%
from pytube import YouTube
Link=input("Enter Link of the youtube")
yt=YouTube(Link)
print("This is my channel")
print("Title of my video",yt.title)
print("Views of my video",yt.views)
print("Length of my video",yt.length)
#print(yt.description)
print("Rating",yt.rating)
# Out:
# Enter Link of the youtubehttps://youtu.be/21Ttaq_OQzY
# This is my channel
# Title of my video Clustering by using Elbow method
# Views of my video 9
# Length of my video 69
# Rating 5.0
