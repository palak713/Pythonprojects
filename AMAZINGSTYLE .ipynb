# %%
pip install speedtest-cli

# %%
import speedtest
wifi=speedtest.Speedtest()
print(wifi.upload())
print(wifi.download())
# Out:
# 272396474.16447276
# 836147049.5788164

# %%
pip install pyfiglet
# Out:
# ...
#      |████████████████████████████████| 870kB 3.9MB/s
# ...

# %%
import pyfiglet
font=pyfiglet.figlet_format('palak')
print(font)
# Out:
#              _       _
#  _ __   __ _| | __ _| | __
# | '_ \ / _` | |/ _` | |/ /
# | |_) | (_| | | (_| |   <
# | .__/ \__,_|_|\__,_|_|\_\
# |_|

# %%
import pyfiglet
font=pyfiglet.figlet_format('Palak loves Python')
print(font)
# Out:
#  ____       _       _      _
# |  _ \ __ _| | __ _| | __ | | _____   _____  ___
# | |_) / _` | |/ _` | |/ / | |/ _ \ \ / / _ \/ __|
# |  __/ (_| | | (_| |   <  | | (_) \ V /  __/\__ \
# |_|   \__,_|_|\__,_|_|\_\ |_|\___/ \_/ \___||___/
#
#  ____        _   _
# |  _ \ _   _| |_| |__   ___  _ __
# | |_) | | | | __| '_ \ / _ \| '_ \
# |  __/| |_| | |_| | | | (_) | | | |
# |_|    \__, |\__|_| |_|\___/|_| |_|
#        |___/
